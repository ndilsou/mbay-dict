# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import json
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi
from dotenv import load_dotenv
import os
from rich import print as rprint
from mbay_dict.core import domain as d
from mbay_dict.core.models import new_object_id

load_dotenv()
# Out:
# True

# %%
uri = os.environ["MONGODB_URI"]

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi("1"))

# Send a ping to confirm a successful connection
try:
    client.admin.command("ping")
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
entries_v1 = list(
    client.get_database("dictionary")
    .get_collection("entries")
    .find(
        projection={
            "headword": 1,
            "french.translation": 1,
            "english.translation": 1,
            "part_of_speech": 1,
        }
    )
)

entries_v2 = list(
    client.get_database("dictionary")
    .get_collection("entries-devel")
    .find(
        projection={
            "headword": 1,
            "french.translation": 1,
            "english.translation": 1,
            "partOfSpeech": 1,
        }
    )
)

# %%
len(entries_v1), len(entries_v2)
# Out:
# (5690, 5132)

# %%
df_v1 = pd.json_normalize(entries_v1).set_index("_id")
df_v2 = pd.json_normalize(entries_v2).set_index("_id")

# %%
df_v1.sort_values(by=["headword"], inplace=True)
df_v2.sort_values(by=["headword"], inplace=True)

# %%
df_v1.head()
# Out:
#                          headword part_of_speech  \
# _id
# 64eca312f6197fd20d76300c      -dé            PRA
# 64eca312f6197fd20d763055     -dɨ́            PRA
# 64eca313f6197fd20d763163      -gē            NAF
# 64eca313f6197fd20d7631ae     -gɨ̄            NAF
# 64eca313f6197fd20d763337      -jè            PRA
#
#                                                          french.translation  \
# _id
# 64eca312f6197fd20d76300c  eux (avec sè quand prononcé sè; donc, sè, mais...
# 64eca312f6197fd20d763055                                  les {forme obj.}.
# 64eca313f6197fd20d763163  particule marquant le pluriel d'une expression...
# 64eca313f6197fd20d7631ae  particule marquant le pluriel de la phrase nom...
# 64eca313f6197fd20d763337                                              nous.
#
#                                                         english.translation
# _id
# 64eca312f6197fd20d76300c  them (with sè when pronounced sè; thus, sè, bu...
# 64eca312f6197fd20d763055                                  them {obj. form}.
# 64eca313f6197fd20d763163  particle marking plural of noun phrase (rare v...
# 64eca313f6197fd20d7631ae            particle marking plural of noun phrase.
# 64eca313f6197fd20d763337                                                us.

# %%
df_v2.head()
# Out:
#                          headword partOfSpeech  \
# _id
# 64fc50f6286b18ef7de0b199     -dɨ́          PRA
# 64fc50f7286b18ef7de0eea2      -gē          NAF
# 64fc50f7286b18ef7de0cebb     -gɨ̄           AF
# 64fc50f7286b18ef7de0e7f2      -jè          PRA
# 64fc50f6286b18ef7de0bc52     -jɨ̀          PRA
#
#                                                          french.translation  \
# _id
# 64fc50f6286b18ef7de0b199                                               leur
# 64fc50f7286b18ef7de0eea2  marquage de particule indiquant le pluriel d'u...
# 64fc50f7286b18ef7de0cebb                                  approximativement
# 64fc50f7286b18ef7de0e7f2                                               nous
# 64fc50f6286b18ef7de0bc52                                               nous
#
#                                              english.translation
# _id
# 64fc50f6286b18ef7de0b199                                   their
# 64fc50f7286b18ef7de0eea2  particle marking plural of noun phrase
# 64fc50f7286b18ef7de0cebb                           approximately
# 64fc50f7286b18ef7de0e7f2                                      us
# 64fc50f6286b18ef7de0bc52                               us {obj.}

# %%
in_v2_not_v1 = df_v2[~df_v2["headword"].isin(df_v1["headword"])]
in_v1_not_v2 = df_v1[~df_v1["headword"].isin(df_v2["headword"])]

# %%
(
    df_v1.drop_duplicates(subset=["headword"]).shape,
    df_v2.drop_duplicates(subset=["headword"]).shape,
)
# Out:
# ((5132, 4), (5132, 4))

# %%
df_v1.shape, df_v2.shape
# Out:
# ((5690, 4), (5132, 4))

# %%
in_v2_not_v1
# Out:
#                                   headword partOfSpeech  \
# _id
# 64fc50f7286b18ef7de0dc42            bàa-bè          CNJ
# 64fc50f7286b18ef7de0bf39  bḭ̀ḭ̄-gìdɨ̀-gījā           NE
# 64fc50f7286b18ef7de0ceea             bíjír          IDS
# 64fc50f6286b18ef7de0b5b9            bògɨ̀r           ID
# 64fc50f6286b18ef7de0b3de         bālē,bàlē           NP
# ...                                    ...          ...
# 64fc50f7286b18ef7de0e375     ɓèe-kàw-kīnjá           NI
# 64fc50f7286b18ef7de0e368         ɓèe-kɨ́lē           NI
# 64fc50f7286b18ef7de0d968             ɓɨ̀lò           NI
# 64fc50f7286b18ef7de0d8ac            ɓɨ̄ngā           VI
# 64fc50f7286b18ef7de0d6ca             ɗɨ̀lè           VT
#
#                                                          french.translation  \
# _id
# 64fc50f7286b18ef7de0dc42                               un instant plus tard
# 64fc50f7286b18ef7de0bf39         obscurité {lit : poil sur le dos du civet}
# 64fc50f7286b18ef7de0ceea  tout est en place dans la vie; avoir tout ce d...
# 64fc50f6286b18ef7de0b5b9  sale (blanc) {couleur de la peau lorsqu'elle e...
# 64fc50f6286b18ef7de0b3de             Samedi {jour traditionnel du balayage}
# ...                                                                     ...
# 64fc50f7286b18ef7de0e375                                 type de champignon
# 64fc50f7286b18ef7de0e368                           type de champignon jaune
# 64fc50f7286b18ef7de0d968                                            esclave
# 64fc50f7286b18ef7de0d8ac                                       être déchiré
# 64fc50f7286b18ef7de0d6ca                     inclinaison, pencher d'un côté
#
#                                                         english.translation
# _id
# 64fc50f7286b18ef7de0dc42                                   an instant later
# 64fc50f7286b18ef7de0bf39             obscurity {lit: hair on back of civet}
# 64fc50f7286b18ef7de0ceea       all set up in life; having everything needed
# 64fc50f6286b18ef7de0b5b9  dirty (white) {color of skin when covered with...
# 64fc50f6286b18ef7de0b3de             Saturday {traditional day of sweeping}
# ...                                                                     ...
# 64fc50f7286b18ef7de0e375                                   type of mushroom
# 64fc50f7286b18ef7de0e368                            type of yellow mushroom
# 64fc50f7286b18ef7de0d968                                              slave
# 64fc50f7286b18ef7de0d8ac                                         be torn up
# 64fc50f7286b18ef7de0d6ca                              tilt, tip to one side
#
# [126 rows x 4 columns]

# %%
in_v1_not_v2
# Out:
#                                 headword part_of_speech  \
# _id
# 64eca312f6197fd20d76300c             -dé            PRA
# 64eca315f6197fd20d764195              -ú             AF
# 64eca314f6197fd20d763d46             -ɔ́             AF
# 64eca313f6197fd20d7633c5       Kàdɨ̀-yòo              N
# 64eca312f6197fd20d762d32         bàa-bèē            AVE
# ...                                  ...            ...
# 64eca312f6197fd20d762d1f          à̰a̰a̰            INJ
# 64eca312f6197fd20d762cf8        ámpɨ̀rmē             NI
# 64eca313f6197fd20d7630f4            èdéè             VT
# 64eca312f6197fd20d762f31  ɓèe-kàw-kɨ̄njá             NI
# 64eca312f6197fd20d762f32        ɓèe-kílē             NI
#
#                                                          french.translation  \
# _id
# 64eca312f6197fd20d76300c  eux (avec sè quand prononcé sè; donc, sè, mais...
# 64eca315f6197fd20d764195  dans, à (suffixe locatif) (suit les noms conte...
# 64eca314f6197fd20d763d46  dans, à {suffixe locatif} (suit les tiges cont...
# 64eca313f6197fd20d7633c5               dieu de la magie, dieu traditionnel.
# 64eca312f6197fd20d762d32  pour un moment, brièvement (communément abrégé...
# ...                                                                     ...
# 64eca312f6197fd20d762d1f                                maintenant tu vois!
# 64eca312f6197fd20d762cf8                     infirmière ; aide hospitalière
# 64eca313f6197fd20d7630f4                                              aider
# 64eca312f6197fd20d762f31                                type de champignon.
# 64eca312f6197fd20d762f32                          type de champignon jaune.
#
#                                                         english.translation
# _id
# 64eca312f6197fd20d76300c  them (with sè when pronounced sè; thus, sè, bu...
# 64eca315f6197fd20d764195  in, at (locative suffix) (follows nouns contai...
# 64eca314f6197fd20d763d46  in, at {locative suffix} (follows stems contai...
# 64eca313f6197fd20d7633c5                     god of magic, traditional god.
# 64eca312f6197fd20d762d32  for a moment, briefly (commonly shortened to b...
# ...                                                                     ...
# 64eca312f6197fd20d762d1f                                      now you see!.
# 64eca312f6197fd20d762cf8                              nurse; hospital aide.
# 64eca313f6197fd20d7630f4                                              help.
# 64eca312f6197fd20d762f31                                  type of mushroom.
# 64eca312f6197fd20d762f32                           type of yellow mushroom.
#
# [127 rows x 4 columns]

# %%
df_v2[df_v2["english.translation"].str.contains("god")]
# Out:
#                                   headword partOfSpeech  \
# _id
# 64fc50f7286b18ef7de0e2ff             Kàdɨ̀           NP
# 64fc50f6286b18ef7de0b7d3  Kàdɨ̀-dɔ̀-ngɔ̀ɔ̀           NP
# 64fc50f7286b18ef7de0eff1             Mò̰ō̰           NP
# 64fc50f7286b18ef7de0d315        bɨ̀rà-ndòo           NT
# 64fc50f6286b18ef7de0a2ac       kóo-dèē-bòo           NP
#
#                                                  french.translation  \
# _id
# 64fc50f7286b18ef7de0e2ff         dieu de la fortune, 'ange gardien'
# 64fc50f6286b18ef7de0b7d3                             dieu des morts
# 64fc50f7286b18ef7de0eff1                    parrain de l'initiation
# 64fc50f7286b18ef7de0d315  parrain de [garçon en cours d'initiation]
# 64fc50f6286b18ef7de0a2ac                         déesse de la pluie
#
#                                          english.translation
# _id
# 64fc50f7286b18ef7de0e2ff    god of fortune, 'guardian angel'
# 64fc50f6286b18ef7de0b7d3                     god of the dead
# 64fc50f7286b18ef7de0eff1             godfather of initiation
# 64fc50f7286b18ef7de0d315  godfather of [boy being initiated]
# 64fc50f6286b18ef7de0a2ac                     goddess of rain

# %%
df_v1[df_v1["headword"].str.contains("^-.$")]
# Out:
#                          headword part_of_speech  \
# _id
# 64eca312f6197fd20d762cd6       -á            PRA
# 64eca312f6197fd20d762cd5       -á             AF
# 64eca313f6197fd20d7630ef       -è             AF
# 64eca313f6197fd20d7630f1       -é             AF
# 64eca313f6197fd20d7632ec       -í            PRA
# 64eca313f6197fd20d7632eb       -í             AF
# 64eca314f6197fd20d763d2d       -ò             AF
# 64eca314f6197fd20d763d2f       -ó             AF
# 64eca315f6197fd20d764195       -ú             AF
# 64eca313f6197fd20d7630f0       -ē             AF
# 64eca313f6197fd20d7632ea       -ī            PRA
# 64eca314f6197fd20d763a1f       -ň            PRA
# 64eca314f6197fd20d763856       -ḿ            PRA
#
#                                                          french.translation  \
# _id
# 64eca312f6197fd20d762cd6                               lui {obj. du verbe}.
# 64eca312f6197fd20d762cd5  dans, à {suffixe locatif} (suit les tiges cont...
# 64eca313f6197fd20d7630ef  particule marquant une phrase interrogative {s...
# 64eca313f6197fd20d7630f1  dans, à {suffixe locatif} (suit les racines co...
# 64eca313f6197fd20d7632ec                                    toi {obl.sing.}
# 64eca313f6197fd20d7632eb  dans, à {suffixe locatif} (suit les racines co...
# 64eca314f6197fd20d763d2d  particule marquant une phrase interrogative (u...
# 64eca314f6197fd20d763d2f  dans, à {suffixe locatif} (suit les racines co...
# 64eca315f6197fd20d764195  dans, à (suffixe locatif) (suit les noms conte...
# 64eca313f6197fd20d7630f0       particule marquant une phrase interrogative.
# 64eca313f6197fd20d7632ea                                   toi [obj. sing.]
# 64eca314f6197fd20d763a1f  avec lui/elle/ça (forme utilisée avec un sujet...
# 64eca314f6197fd20d763856                                moi [oblique], mon.
#
#                                                         english.translation
# _id
# 64eca312f6197fd20d762cd6                       him, her, it {obj. of verb}.
# 64eca312f6197fd20d762cd5  in, at {locative suffix} (follows stems contai...
# 64eca313f6197fd20d7630ef  particle marking an interrogative sentence {as...
# 64eca313f6197fd20d7630f1  in, at {locative suffix} (follows stems contai...
# 64eca313f6197fd20d7632ec                                   you {obl.sing.}.
# 64eca313f6197fd20d7632eb  in, at {locative suffix} (follows stems contai...
# 64eca314f6197fd20d763d2d  particle marking an interrogative sentence (us...
# 64eca314f6197fd20d763d2f  in, at {locative suffix} (follows stems contai...
# 64eca315f6197fd20d764195  in, at (locative suffix) (follows nouns contai...
# 64eca313f6197fd20d7630f0        particle marking an interrogative sentence.
# 64eca313f6197fd20d7632ea                                  you [obj. sing.].
# 64eca314f6197fd20d763a1f  with him/her/it (form used with singular subj....
# 64eca314f6197fd20d763856                                  me [oblique], my.

# %%
df_v2[df_v2["headword"].str.contains("^-.$")]
# Out:
#                          headword partOfSpeech  \
# _id
# 64fc50f7286b18ef7de0e7ec       -á           AF
# 64fc50f7286b18ef7de0d8aa       -è           AF
# 64fc50f7286b18ef7de0e811       -é           AF
# 64fc50f7286b18ef7de0e80f       -í           AF
# 64fc50f7286b18ef7de0e839       -ò           AF
# 64fc50f7286b18ef7de0e80d       -ó           AF
# 64fc50f7286b18ef7de0e7ef       -ē           AF
# 64fc50f7286b18ef7de0ca78       -ī          PRA
# 64fc50f7286b18ef7de0bf2a       -ň          PRA
# 64fc50f6286b18ef7de0a0ea       -ḿ          PRA
#
#                                                          french.translation  \
# _id
# 64fc50f7286b18ef7de0e7ec                          dans, à {suffixe locatif}
# 64fc50f7286b18ef7de0d8aa  particule marquant une phrase interrogative {s...
# 64fc50f7286b18ef7de0e811                          dans, à {suffixe locatif}
# 64fc50f7286b18ef7de0e80f                          dans, à {suffixe locatif}
# 64fc50f7286b18ef7de0e839        particule marquant une phrase interrogative
# 64fc50f7286b18ef7de0e80d                          dans, à {suffixe locatif}
# 64fc50f7286b18ef7de0e7ef        particule marquant une phrase interrogative
# 64fc50f7286b18ef7de0ca78                                               vous
# 64fc50f7286b18ef7de0bf2a                                  par lui/elle/cela
# 64fc50f6286b18ef7de0a0ea                                                mon
#
#                                                         english.translation
# _id
# 64fc50f7286b18ef7de0e7ec                           in, at {locative suffix}
# 64fc50f7286b18ef7de0d8aa  particle marking an interrogative sentence {as...
# 64fc50f7286b18ef7de0e811                           in, at {locative suffix}
# 64fc50f7286b18ef7de0e80f                           in, at {locative suffix}
# 64fc50f7286b18ef7de0e839         particle marking an interrogative sentence
# 64fc50f7286b18ef7de0e80d                           in, at {locative suffix}
# 64fc50f7286b18ef7de0e7ef         particle marking an interrogative sentence
# 64fc50f7286b18ef7de0ca78                                   you [obj. sing.]
# 64fc50f7286b18ef7de0bf2a                           by or through him/her/it
# 64fc50f6286b18ef7de0a0ea                                                 my

# %%
entries_v1_full = list(
    client.get_database("dictionary").get_collection("entries").find()
)

# %%
new_entries = []
for id in in_v1_not_v2.index:
    entry_v1 = next(item for item in entries_v1_full if item["_id"] == id)
    id = entry_v1["_id"]
    examples = [
        d.Example(
            id=example["_id"],
            parent_id=d.ParentId(id=id, type="entry"),
            mbay=example["mbay"],
            english=d.Translation.from_text(example["english_translation"]),
            french=d.Translation.from_text(example["french_translation"]),
            sound_filename=example["sound_filename"],
        )
        for example in entry_v1["examples"]
    ]
    entry = d.Entry(
        id=id,
        headword=entry_v1["headword"],
        part_of_speech=entry_v1["part_of_speech"],
        english=d.Translation.from_text(entry_v1["english"]["translation"]),
        french=d.Translation.from_text(entry_v1["french"]["translation"]),
        sound_filename=entry_v1["sound_filename"],
        examples=examples,
        expressions=[],
    )
    new_entries.append(entry.model_dump(by_alias=True))

# %%
rprint(entry_v1)
rprint(entry)
# Out:
# {
#     '_id': ObjectId('64eca312f6197fd20d762f32'),
#     'created_at': '2023-08-19T22:59:14Z',
#     'updated_at': '2023-08-19T22:59:14Z',
#     'headword': 'ɓèe-kílē',
#     'part_of_speech': 'NI',
#     'sound_filename': 'BBat_to_BBe174.mp3',
#     'french': {'translation': 'type de champignon jaune.', 'key': 't'},
#     'english': {'translation': 'type of yellow mushroom.', 'key': 't'},
#     'examples': [
#         {
#             'created_at': '2023-08-19T22:59:14Z',
#             'updated_at': '2023-08-19T22:59:14Z',
#             'entry_id': 610,
#             'mbay': 'ɓèe-kílē ì ɓèe kɨ́ dɔ̀-á tátɨ́ ngá̰y àĺ nà̰ rō-á kìrē tītɨ̄ rō kílē bè.',
#             'english_translation': '____ is a mushroom whose head is not very wide, and its color is like that of
# the weaver.',
#             'french_translation': "____ est un champignon dont la tête n'est pas très large, et sa couleur est
# comme celle du tisserand.",
#             'sound_filename': 'RCJ6_107_08.mp3',
#             '_id': ObjectId('64eca312f6197fd20d760d0f')
#         }
#     ]
# }
# Entry(
#     id=ObjectId('64eca312f6197fd20d762f32'),
#     created_at=datetime.datetime(2023, 9, 9, 12, 27, 55, 778434, tzinfo=datetime.timezone.utc),
#     updated_at=datetime.datetime(2023, 9, 9, 12, 27, 55, 778434, tzinfo=datetime.timezone.utc),
#     headword='ɓèe-kílē',
#     part_of_speech='NI',
#     sound_filename='BBat_to_BBe174.mp3',
#     french=Translation(translation='type de champignon jaune.', key='t'),
#     english=Translation(translation='type of yellow mushroom.', key='t'),
#     related_word=None,
#     grammatical_note=None,
#     examples=[
#         Example(
#             id=ObjectId('64eca312f6197fd20d760d0f'),
#             created_at=datetime.datetime(2023, 9, 9, 12, 27, 55, 778420, tzinfo=datetime.timezone.utc),
#             updated_at=datetime.datetime(2023, 9, 9, 12, 27, 55, 778420, tzinfo=datetime.timezone.utc),
#             parent_id=ParentId(id=ObjectId('64eca312f6197fd20d762f32'), type='entry'),
#             mbay='ɓèe-kílē ì ɓèe kɨ́ dɔ̀-á tátɨ́ ngá̰y àĺ nà̰ rō-á kìrē tītɨ̄ rō kílē bè.',
#             english=Translation(
#                 translation='____ is a mushroom whose head is not very wide, and its color is like that of the
# weaver.',
#                 key='MISC'
#             ),
#             french=Translation(
#                 translation="____ est un champignon dont la tête n'est pas très large, et sa couleur est comme
# celle du tisserand.",
#                 key='MISC'
#             ),
#             sound_filename='RCJ6_107_08.mp3'
#         )
#     ],
#     expressions=[]
# )

# %%
rprint(new_entries[-1])
# Out:
# {
#     '_id': ObjectId('64eca312f6197fd20d762f32'),
#     'createdAt': '2023-09-09T12:27:55Z',
#     'updatedAt': '2023-09-09T12:27:55Z',
#     'headword': 'ɓèe-kílē',
#     'partOfSpeech': 'NI',
#     'soundFilename': 'BBat_to_BBe174.mp3',
#     'french': {'translation': 'type de champignon jaune.', 'key': 't'},
#     'english': {'translation': 'type of yellow mushroom.', 'key': 't'},
#     'relatedWord': None,
#     'grammaticalNote': None,
#     'examples': [
#         {
#             '_id': ObjectId('64eca312f6197fd20d760d0f'),
#             'createdAt': '2023-09-09T12:27:55Z',
#             'updatedAt': '2023-09-09T12:27:55Z',
#             'parentId': {'id': ObjectId('64eca312f6197fd20d762f32'), 'type': 'entry'},
#             'mbay': 'ɓèe-kílē ì ɓèe kɨ́ dɔ̀-á tátɨ́ ngá̰y àĺ nà̰ rō-á kìrē tītɨ̄ rō kílē bè.',
#             'english': {
#                 'translation': '____ is a mushroom whose head is not very wide, and its color is like that of the
# weaver.',
#                 'key': 'MISC'
#             },
#             'french': {
#                 'translation': "____ est un champignon dont la tête n'est pas très large, et sa couleur est comme
# celle du tisserand.",
#                 'key': 'MISC'
#             },
#             'soundFilename': 'RCJ6_107_08.mp3'
#         }
#     ],
#     'expressions': []
# }

# %%
entries_v2_full = list(
    client.get_database("dictionary").get_collection("entries-devel").find()
)

# %%
rprint(new_entries[0], entries_v2_full[0])
# Out:
# {
#     '_id': ObjectId('64eca312f6197fd20d76300c'),
#     'createdAt': '2023-09-09T12:27:55Z',
#     'updatedAt': '2023-09-09T12:27:55Z',
#     'headword': '-dé',
#     'partOfSpeech': 'PRA',
#     'soundFilename': 'De3W.mp3',
#     'french': {'translation': 'eux (avec sè quand prononcé sè; donc, sè, mais sè).', 'key': 'e'},
#     'english': {'translation': 'them (with sè when pronounced sè; thus, sè, but sè).', 'key': 't'},
#     'relatedWord': None,
#     'grammaticalNote': None,
#     'examples': [
#         {
#             '_id': ObjectId('64eca312f6197fd20d760e84'),
#             'createdAt': '2023-09-09T12:27:55Z',
#             'updatedAt': '2023-09-09T12:27:55Z',
#             'parentId': {'id': ObjectId('64eca312f6197fd20d76300c'), 'type': 'entry'},
#             'mbay': 'Ngōn-kó̰o̰ ngōn-kɨ́-màndɨ̀ nò kɨ́-dūú kɨ́ dìngá àn kɨ̀ n-àw̄ sè-dé.',
#             'english': {'translation': 'The younger brother of the girl said he would go with them.', 'key': 't'},
#             'french': {'translation': "Le frère cadet de la fille a dit qu'il irait avec eux.", 'key': 'l'},
#             'soundFilename': 'SeSS1.mp3'
#         }
#     ],
#     'expressions': []
# }
# {
#     '_id': ObjectId('64fc50f7286b18ef7de0db22'),
#     'createdAt': '2023-09-09T11:03:19Z',
#     'updatedAt': '2023-09-09T11:03:19Z',
#     'headword': 'màn̄-kò̰o̰',
#     'partOfSpeech': 'NI',
#     'soundFilename': 'Tape13MbayBB232.mp3',
#     'french': {'translation': 'inondation', 'key': 'i'},
#     'english': {'translation': 'flooding', 'key': 'f'},
#     'relatedWord': None,
#     'grammaticalNote': None,
#     'examples': [
#         {
#             '_id': ObjectId('64fc50f7286b18ef7de0db23'),
#             'createdAt': '2023-09-09T11:03:19Z',
#             'updatedAt': '2023-09-09T11:03:19Z',
#             'parentId': {'id': ObjectId('64fc50f7286b18ef7de0db22'), 'type': 'entry'},
#             'mbay': 'Dà-nā̰a̰ màn̄-kò̰o̰ tɨ́',
#             'english': {'translation': 'during the season of flooding', 'key': 'd'},
#             'french': {'translation': 'pendant la saison des inondations', 'key': 'p'},
#             'soundFilename': 'Tape13MbayBB234.mp3'
#         }
#     ],
#     'expressions': []
# }

# %%
output = [*entries_v2_full, *new_entries]

# %%
from pathlib import Path

output_filepath = Path("../../data/xml_processing/completed_mongo_items.json")

# %%
from mbay_dict.core.serializers import CustomJSONEncoder
from bson.json_util import dumps

print(f"Saving data to {output_filepath}")
with open(output_filepath, "w") as f:
    f.write(dumps(output, cls=CustomJSONEncoder, ensure_ascii=False))
# Out:
# Saving data to ../../data/xml_processing/completed_mongo_items.json
